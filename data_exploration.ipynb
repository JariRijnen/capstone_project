# %%
import pandas as pd

# %%
df = pd.read_csv(r"data\US_weather\US_weather_all.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      STATION                                    NAME  LATITUDE  \
# 0           0  USW00014607  CARIBOU WEATHER FORECAST OFFICE, ME US   46.8705
# 1           1  USW00014607  CARIBOU WEATHER FORECAST OFFICE, ME US   46.8705
# 2           2  USW00014607  CARIBOU WEATHER FORECAST OFFICE, ME US   46.8705
# 3           3  USW00014607  CARIBOU WEATHER FORECAST OFFICE, ME US   46.8705
# 4           4  USW00014607  CARIBOU WEATHER FORECAST OFFICE, ME US   46.8705
#
#    LONGITUDE  ELEVATION        DATE  AWND  EVAP    FMTM  PGTM  PRCP  SN52  \
# 0   -68.0173      190.2  1991-12-31   2.8   NaN  1050.0   NaN   0.0   NaN
# 1   -68.0173      190.2  1992-01-01   2.0   NaN  1250.0   NaN   0.0   NaN
# 2   -68.0173      190.2  1992-01-02   1.8   NaN  1651.0   NaN   0.0   NaN
# 3   -68.0173      190.2  1992-01-03   1.4   NaN  1850.0   NaN   0.0   NaN
# 4   -68.0173      190.2  1992-01-04   0.9   NaN  1451.0   NaN   0.0   NaN
#
# ...

# %%
s = df['STATION'].value_counts()

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.loc[:, ~df.columns.isin(['STATION', 'LATITUDE', 'LONGITUDE', 'DATE', 'ELEVATION'])].set_index('NAME').isna().groupby(level=0).mean().round(4).mul(100)

# %% [markdown]
# # wild fires data

# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect("data\wildfires\FPA_FOD_20170508.sqlite")

# %%
df = pd.read_sql_query("SELECT * FROM 'Fires'", con)
df.columns
# Out:
# Index(['OBJECTID', 'FOD_ID', 'FPA_ID', 'SOURCE_SYSTEM_TYPE', 'SOURCE_SYSTEM',
#        'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID',
#        'NWCG_REPORTING_UNIT_NAME', 'SOURCE_REPORTING_UNIT',
#        'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID',
#        'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'FIRE_NAME',
#        'ICS_209_INCIDENT_NUMBER', 'ICS_209_NAME', 'MTBS_ID', 'MTBS_FIRE_NAME',
#        'COMPLEX_NAME', 'FIRE_YEAR', 'DISCOVERY_DATE', 'DISCOVERY_DOY',
#        'DISCOVERY_TIME', 'STAT_CAUSE_CODE', 'STAT_CAUSE_DESCR', 'CONT_DATE',
#        'CONT_DOY', 'CONT_TIME', 'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE',
#        'LONGITUDE', 'OWNER_CODE', 'OWNER_DESCR', 'STATE', 'COUNTY',
#        'FIPS_CODE', 'FIPS_NAME', 'Shape'],
#       dtype='object')

# %%
df.head()
# Out:
#    OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0         1       1  FS-1418826                FED   FS-FIRESTAT
# 1         2       2  FS-1418827                FED   FS-FIRESTAT
# 2         3       3  FS-1418835                FED   FS-FIRESTAT
# 3         4       4  FS-1418845                FED   FS-FIRESTAT
# 4         5       5  FS-1418847                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME  \
# 0                    FS                USCAPNF    Plumas National Forest
# 1                    FS                USCAENF  Eldorado National Forest
# 2                    FS                USCAENF  Eldorado National Forest
# 3                    FS                USCAENF  Eldorado National Forest
# 4                    FS                USCAENF  Eldorado National Forest
#
#   SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME LOCAL_FIRE_REPORT_ID  \
# ...

# %%
df1000 = df.iloc[:1000,:]

# %%
df.to_parquet('data/wildfires.parquet', compression=None)

# %%
len(df)
# Out:
# 1880465

# %%
df = pd.read_parquet("data\wildfires.parquet")
pd.set_option("display.max_columns", None)
df.head(5)
# Out:
#    OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0         1       1  FS-1418826                FED   FS-FIRESTAT
# 1         2       2  FS-1418827                FED   FS-FIRESTAT
# 2         3       3  FS-1418835                FED   FS-FIRESTAT
# 3         4       4  FS-1418845                FED   FS-FIRESTAT
# 4         5       5  FS-1418847                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME  \
# 0                    FS                USCAPNF    Plumas National Forest
# 1                    FS                USCAENF  Eldorado National Forest
# 2                    FS                USCAENF  Eldorado National Forest
# 3                    FS                USCAENF  Eldorado National Forest
# 4                    FS                USCAENF  Eldorado National Forest
#
#   SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME LOCAL_FIRE_REPORT_ID  \
# ...

# %%
df.columns
# Out:
# Index(['OBJECTID', 'FOD_ID', 'FPA_ID', 'SOURCE_SYSTEM_TYPE', 'SOURCE_SYSTEM',
#        'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID',
#        'NWCG_REPORTING_UNIT_NAME', 'SOURCE_REPORTING_UNIT',
#        'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID',
#        'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'FIRE_NAME',
#        'ICS_209_INCIDENT_NUMBER', 'ICS_209_NAME', 'MTBS_ID', 'MTBS_FIRE_NAME',
#        'COMPLEX_NAME', 'FIRE_YEAR', 'DISCOVERY_DATE', 'DISCOVERY_DOY',
#        'DISCOVERY_TIME', 'STAT_CAUSE_CODE', 'STAT_CAUSE_DESCR', 'CONT_DATE',
#        'CONT_DOY', 'CONT_TIME', 'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE',
#        'LONGITUDE', 'OWNER_CODE', 'OWNER_DESCR', 'STATE', 'COUNTY',
#        'FIPS_CODE', 'FIPS_NAME'],
#       dtype='object')

# %%
df['LOCAL_FIRE_REPORT_ID'][~df['LOCAL_FIRE_REPORT_ID'].isna()]
# Out:
# 0               1
# 1              13
# 2              27
# 3              43
# 4              44
#             ...
# 1880460    591814
# 1880461    569419
# 1880462    574245
# 1880463    570462
# 1880464    535436
# Name: LOCAL_FIRE_REPORT_ID, Length: 421179, dtype: object

# %%
df = pd.read_sql_query("SELECT FIRE_YEAR,STAT_CAUSE_DESCR,LATITUDE,LONGITUDE,STATE,DISCOVERY_DATE,FIRE_SIZE FROM 'Fires'", con)
print(df.head())

# %%
df.groupby(df.columns.tolist(),as_index=False).size()

# %%
import psycopg2

# %%
conn = psycopg2.connect("host=localhost dbname=capstone user=postgres")
cur = conn.cursor()

# %%
# Out:
#   Input In [52]
#     postgres://localhost:5439/capstone
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # copy from files

# %%
conn_string = "postgresql://postgres@localhost:5432/capstone"

# %%
# %load_ext sql

# %%
# %sql $conn_string

# %%
query = ("""
    COPY staging_weather
    FROM 'C://Users//Public//US_weather_all.csv'
    DELIMITER ','
    CSV HEADER;
    """)
cur.execute(query)
conn.commit()

# %%
cur.execute("rollback;")
